# %% [markdown]
# ## Private LB API sample code

# %%
from privateLB import API

key = 'sNfoTDclWrvFGpIEFDEXvj+EaCjLrOILF7IYehdRCcYBxnMP0zna40R1UmY6qfWBG0gJ16c3T8ManHwvhACk7w=='

# 날짜는 최근의 일자로 업데이트 해줘야만 불러올 수 있습니다.
dj = API('20210525','2000','dangjin',key).get_data(preprocess=True)
uls = API('20210525','2000','ulsan',key).get_data(preprocess=True)

# %%
help(API.__init__)
# Out:
# Help on function __init__ in module privateLB:
#
# __init__(self, base_date, base_time, location, key)
#     base_date: str, format:'YYYYMMDD'(e.g. '20210522'). 예보 발표일자. API로는 최근 1일간의 자료만을 불러올 수 있다는 점 유의.
#     base_time: str, format: 'HHMM'(e.g. '2000' for 20시). 예보 발표시각. 0200, 0500, 0800, 1100, 1400, 1700, 2000, 2300 중 하나여야 함.
#     location: str, 'dangjin' or 'ulsan'.
#     key: 기상청 API 일반 인증키(decoding)`

# %%
display(dj)
display(uls)
# Out:
#                   time   Humidity     Cloud  Temperature  WindDirection  \
# 1  2021-05-26 01:00:00  76.666667  1.000000    11.666667     227.000000
# 2  2021-05-26 02:00:00  78.333333  1.000000    11.333333     201.000000
# 3  2021-05-26 03:00:00  80.000000  1.000000    11.000000     175.000000
# 4  2021-05-26 04:00:00  81.666667  1.000000    11.333333     170.333333
# 5  2021-05-26 05:00:00  83.333333  1.000000    11.666667     165.666667
# 6  2021-05-26 06:00:00  85.000000  1.000000    12.000000     161.000000
# 7  2021-05-26 07:00:00  76.666667  1.000000    14.000000     162.333333
# 8  2021-05-26 08:00:00  68.333333  1.000000    16.000000     163.666667
# 9  2021-05-26 09:00:00  60.000000  1.000000    18.000000     165.000000
# 10 2021-05-26 10:00:00  50.000000  1.666667    19.666667     174.000000
# 11 2021-05-26 11:00:00  40.000000  2.333333    21.333333     183.000000
# 12 2021-05-26 12:00:00  30.000000  3.000000    23.000000     192.000000
# ...
