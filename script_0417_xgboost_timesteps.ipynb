# %%
# ================================================================================ #
# =========================== Goolge Colab File Upload =========================== #
# ================================================================================ #

from google.colab import drive
drive.mount('/content/drive')

from google.colab import output
# !cp 파일1 파일2 # 파일1을 파일2로 복사 붙여넣기
# !cp "/content/drive/MyDrive/Colab Notebooks/동서발전 태양광 발전량 예측 경진대회/data.zip" "data.zip"
# data.zip을 현재 디렉터리에 압축해제
# !unzip "data.zip"
output.clear()

import os

# %%
# path
path = "./"
dangjin_fcst_data_path = path + "dangjin_fcst_data.csv"
dangjin_obs_data_path = path + "dangjin_obs_data.csv"
energy_data_path = path + "energy.csv"
ulsan_fcst_data_path = path + "ulsan_fcst_data.csv"
ulsan_obs_data_path = path + "ulsan_obs_data.csv"
site_info_path = path + "site_info.csv"

# import library 
import numpy as np
import pandas as pd
import scipy as sp
import tensorflow as tf
#import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import os
import glob

# file convert to pandas data
dangjin_fcst_data = pd.read_csv(dangjin_fcst_data_path)
dangjin_obs_data = pd.read_csv(dangjin_obs_data_path)
energy_data = pd.read_csv(energy_data_path)
ulsan_fcst_data = pd.read_csv(ulsan_fcst_data_path)
ulsan_obs_data = pd.read_csv(ulsan_obs_data_path)
site_info = pd.read_csv(site_info_path)


# ======================================================================== #
# =========================== 이하는 공통 사항  =========================== #
# ======================================================================== #

'''
- 일자, 시각 등은 'time' 이라는 변수명으로 통일
- 그 외의 변수명은 '변수명_파일명' 으로 지정(ulsan, dangjin)
- 가정하길 ulsan 데이터와 dangjin 데이터는 서로 무관하다. 
- 이후에 NAN 데이터는 dropna()를 이용해 모두 소거 예정
- 하나의 데이터셋을 구축한 뒤, 상관관게 분석 + ADF test 등을 진행
'''

dangjin_fcst_data.rename(
    columns = {
        "Forecast time":"time", 
        "forecast":"forecast_fcst", 
        "Temperature":"temp_fcst",
        "Humidity":"humid_fcst",
        "WindSpeed":"ws_fcst",
        "WindDirection":"wd_fcst",
        "Cloud":"cloud_fcst"
        }, inplace = True)

dangjin_obs_data.rename(
    columns = {
        "일시":"time",
        "기온(°C)":"temp_obs",
        "풍속(m/s)":"ws_obs",
        "풍향(16방위)":"wd_obs",
        "습도(%)":"humid_obs",
        "전운량(10분위)":"cloud_obs"
    }, inplace = True)

ulsan_fcst_data.rename(
    columns = {
        "Forecast time":"time", 
        "forecast":"forecast_fcst", 
        "Temperature":"temp_fcst",
        "Humidity":"humid_fcst",
        "WindSpeed":"ws_fcst",
        "WindDirection":"wd_fcst",
        "Cloud":"cloud_fcst"
    }, inplace = True)

ulsan_obs_data.rename(
    columns = {
        "일시":"time",
        "기온(°C)":"temp_obs",
        "풍속(m/s)":"ws_obs",
        "풍향(16방위)":"wd_obs",
        "습도(%)":"humid_obs",
        "전운량(10분위)":"cloud_obs"
    }, inplace = True)

dangjin_obs_data = dangjin_obs_data.drop(columns = ["지점", "지점명"])
ulsan_obs_data = ulsan_obs_data.drop(columns = ["지점","지점명"])

# fcst_data 데이터 전처리
# time + forecast -> time으로 전환, 이후 중복되는 값은 평균 처리 

dangjin_fcst_data["time_fcst"] = pd.to_datetime(dangjin_fcst_data["time"].copy()) + dangjin_fcst_data["forecast_fcst"].copy().astype("timedelta64[h]")
dangjin_fcst_data = dangjin_fcst_data.groupby("time_fcst", as_index = False).mean()
dangjin_fcst_data = dangjin_fcst_data.drop(columns = ["forecast_fcst"])

ulsan_fcst_data["time_fcst"] = pd.to_datetime(ulsan_fcst_data["time"].copy()) + ulsan_fcst_data["forecast_fcst"].copy().astype("timedelta64[h]")
ulsan_fcst_data = ulsan_fcst_data.groupby("time_fcst", as_index = False).mean()
ulsan_fcst_data = ulsan_fcst_data.drop(columns = ["forecast_fcst"])

ulsan_fcst_data.rename(columns = {"time_fcst":"time"}, inplace = True)
dangjin_fcst_data.rename(columns = {"time_fcst":"time"}, inplace = True)

ulsan_fcst_data = ulsan_fcst_data.astype({"time":"object"})
dangjin_fcst_data = dangjin_fcst_data.astype({"time":"object"})

dangjin_obs_data["time"] = pd.to_datetime(dangjin_obs_data["time"].copy(), format='%Y-%m-%d %H:%M:%S')
dangjin_obs_data = dangjin_obs_data.astype({"time":"object"})

ulsan_obs_data["time"] = pd.to_datetime(ulsan_obs_data["time"].copy(), format='%Y-%m-%d %H:%M:%S')
ulsan_obs_data = ulsan_obs_data.astype({"time":"object"})

# energy_data는 time 항목이 string으로 저장되어 있다. 이를 timestamp로 처리해야한다. 

energy_data_time_tmp = energy_data["time"].copy()

for i in range(energy_data.shape[0]):
    if energy_data["time"][i][-8:] == "24:00:00":
        energy_data["time"][i] = energy_data_time_tmp[i].replace("24:00:00", " 00:00:00")

    energy_data["time"][i] = pd.Timestamp(energy_data["time"][i])

energy_data = energy_data.astype({"time":"object"})

# 전 데이터 NAN 처리

dangjin_fcst_data = dangjin_fcst_data.dropna()
dangjin_obs_data = dangjin_obs_data.dropna()
energy_data = energy_data.dropna()
ulsan_fcst_data = ulsan_fcst_data.dropna()
ulsan_obs_data = ulsan_obs_data.dropna()

# fcst_data['time'] time interval: 3hour -> 1hour로 축소 필요
# Lagrangian Interpolation

def interpolation(df):

    df_copy = df.copy()
    var_names = df.columns

    total_s = list()
    time_list = list()
    
    for var_name in var_names:
        s = list()
        for i in range(df_copy.shape[0] - 1):
            timedeltas = df_copy["time"][i+1] - df_copy["time"][i]
            n_intervals = int(timedeltas / np.timedelta64(1, "h"))

            for j in range(n_intervals):
        
                if var_name == "time":
                    time_stamps = df_copy["time"][i] + timedeltas * j / n_intervals
                    time_list.append(time_stamps)
                else:
                    add_ = df_copy[var_name][i] + (df_copy[var_name][i+1] - df_copy[var_name][i]) / n_intervals * j
                    s.append(add_)

        if var_name == "time":
            time_list = np.array(time_list).reshape(-1,1)
            total_s.append(time_list)
        else:
            s = np.array(s).reshape(-1,1)
            total_s.append(s)

    total_s = np.array(total_s).T.reshape(-1, len(var_names))
    df_converted = pd.DataFrame(total_s, columns = var_names)

    return df_converted

dangjin_fcst_data = interpolation(dangjin_fcst_data.copy())
ulsan_fcst_data = interpolation(ulsan_fcst_data.copy())

ulsan_fcst_data = ulsan_fcst_data.astype({"time":"object"})
dangjin_fcst_data = dangjin_fcst_data.astype({"time":"object"})

# total dataset 구성

from functools import reduce

list_dangjin = [dangjin_fcst_data, dangjin_obs_data, energy_data[["time","dangjin_floating","dangjin_warehouse","dangjin"]].copy()]
list_ulsan = [ulsan_fcst_data, ulsan_obs_data, energy_data[["time","ulsan"]].copy()]

dangjin_data = reduce(lambda  left,right: pd.merge(left, right, on=['time'], how='inner'), list_dangjin)
ulsan_data = reduce(lambda  left,right: pd.merge(left, right, on=['time'], how='inner'), list_ulsan)

display(dangjin_data)
display(ulsan_data)

'''
- dangjin 및 ulsan 지역 내 모든 측정/예측 변수를 하나의 데이터셋에 포함
- 중복되는 시간대에 대해서만 선별 후 하나의 데이터셋으로 통합
'''

# EDA 
import seaborn as sns
from scipy import stats

# stats.pearsonr을 이용해 각 변수간 pearson correlation을 구한다. 
# 이후 dangjin과 ulsan datasets에 대한 heatmap을 그린다. 

var_names = dangjin_data.copy().drop(columns = ["dangjin_floating","dangjin_warehouse", "dangjin", "time"]).columns

print("statistical analysis with dangjin_floating: pearson correlation coefficient")
print("===========================================================================")
for var_name in var_names:
    r, p = stats.pearsonr(dangjin_data[var_name], dangjin_data["dangjin_floating"])
    log = "variable: %s, pearson's r : %5f, p-value: %5f"
    fmt = log %(var_name, r,p)
    print(fmt)
print("===========================================================================\n")
print("statistical analysis with dangjin_warehouse: pearson correlation coefficient")
print("===========================================================================")
for var_name in var_names:
    r, p = stats.pearsonr(dangjin_data[var_name], dangjin_data["dangjin_warehouse"])
    log = "variable: %s, pearson's r : %5f, p-value: %5f"
    fmt = log %(var_name, r,p)
    print(fmt)
print("===========================================================================\n")
print("statistical analysis with dangjin: pearson correlation coefficient")
print("===========================================================================")
for var_name in var_names:
    r, p = stats.pearsonr(dangjin_data[var_name], dangjin_data["dangjin"])
    log = "variable: %s, pearson's r : %5f, p-value: %5f"
    fmt = log %(var_name, r,p)
    print(fmt)
print("===========================================================================\n")

dangjin_data.corr("pearson")
sns.heatmap(dangjin_data.corr("pearson"))

# ulsan data

var_names = ulsan_data.copy().drop(columns = ["ulsan", "time"]).columns

print("statistical analysis with ulsan: pearson correlation coefficient")
print("===========================================================================")
for var_name in var_names:
    r, p = stats.pearsonr(ulsan_data[var_name], ulsan_data["ulsan"])
    log = "variable: %s, pearson's r : %5f, p-value: %5f"
    fmt = log %(var_name, r,p)
    print(fmt)
print("===========================================================================\n")

ulsan_data.corr("pearson")
sns.heatmap(ulsan_data.corr("pearson"))

# supervised learning을 위한 preprocessing

def series_to_supervised(data, x_name, y_name, n_in, n_out, dropnan = False):

    '''
    - function: to convert series data to be supervised 
    - data: pd.DataFrame
    - x_name: the name of variables used to predict
    - y_name: the name of variables for prediction
    - n_in: number(or interval) of series used to predict
    - n_out: number of series for prediction

    - 24 * 30 -> 720개의 output을 예측
    - 필요한 input -> 최소 720개 이상
    - 아이디어: 1일 예측, 예측치를 다시 입력값으로 받게 진행, 이 경우 output:24

    '''

    data_copy = data.copy()
    cols, names = list(), list()

    for i in range(n_in, 0, -1):
        #cols.append(data_copy[x_name].shift(i)) # col: [data_copy.shift(n_in), .... data_copy.shift(1)]
        cols.append(data_copy[x_name].shift(i))
        names += [("%s(t-%d)"%(name, i)) for name in x_name]
    
    for i in range(0, n_out):
        y = data_copy[y_name]
        cols.append(y.shift(-i))
        # cols:[data_copy.shift(n_in-1), .... data_copy.shift(1), data_copy[y_name].shift(0)....data_copy[y_name].shift(-n_out + 1)]

        if i == 0:
            names += [("%s(t)"%(name)) for name in y_name]
        else:
            names += [("%s(t+%d)"%(name, i)) for name in y_name]

    agg = pd.concat(cols, axis = 1)
    agg.columns = names

    if dropnan:
        agg.dropna(inplace = True)
    
    return agg

# model architecture

# !sudo pip install xgboost
# !sudo pip install --upgrade xgboost

import xgboost as xgb

'''
- input data와 output data의 timesteps 조정
- 입력값은 예측하고자 하는 변수를 그대로 적용
'''

# dangjin floating
x_name = ["dangjin_floating"]
y_name = ["dangjin_floating"]
n_features = len(x_name)
n_in = 24 * 30
n_out = 1
ratio = 0.8 # train size ratio

dangjin_data_supervised = series_to_supervised(dangjin_data, x_name, y_name, n_in, n_out, dropnan = True)

x_data = dangjin_data_supervised.values[:,:-n_out * len(y_name)]
y_data = dangjin_data_supervised.values[:,-n_out * len(y_name):]

# train_test split
data_size = x_data.shape[0]
train_size = int(data_size * ratio)

x_train = x_data[0:train_size]
x_test = x_data[train_size:]

y_train = y_data[0:train_size]
y_test = y_data[train_size:]

# build model
params = {
    "booster":"dart",
    "objective":"reg:squarederror",
    "learning_rate":0.001,
    "max_depth":15,
    "n_estimators":1000,
    "nthread":-1,
    "gamma":10.0,
    "subsample":0.8,
    "colsample_bytree":0.8,
    "colsample_bylevel":0.8,
    "min_child_weight":3,
    "reg_lambda":1.0,
    "reg_alpha":0.1
}

# build model and parameter setting

def build_xgb(params):
    model = xgb.XGBRegressor(
        booster = params["booster"],
        objective = params["objective"],
        learning_rate = params["learning_rate"],    
        max_depth = params["max_depth"],
        n_estimators = params["n_estimators"],
        nthread = params["nthread"],
        gamma = params["gamma"],
        min_child_weight = params["min_child_weight"],
        subsample = params["subsample"],
        reg_lambda = params["reg_lambda"],
        reg_alpha = params["reg_alpha"],
        colsample_bytree = params["colsample_bytree"],
        colsample_bylevel = params["colsample_bylevel"]
    )
    return model

model = build_xgb(params)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       time temp_fcst  ... dangjin_warehouse dangjin
# 0      2018-07-17 12:00:00   29.1111  ...             394.0     639
# 1      2018-07-17 13:00:00   29.1267  ...             414.0     686
# 2      2018-08-01 01:00:00   25.6667  ...               0.0       0
# 3      2018-08-01 02:00:00   25.3333  ...               0.0       0
# 4      2018-08-01 03:00:00        25  ...               0.0       0
# ...                    ...       ...  ...               ...     ...
# 21593  2021-01-31 19:00:00   6.13333  ...               0.0       0
# 21594  2021-01-31 20:00:00   6.06667  ...               0.0       0
# 21595  2021-01-31 21:00:00         6  ...               0.0       0
# 21596  2021-01-31 22:00:00   6.21212  ...               0.0       0
# 21597  2021-01-31 23:00:00   6.42424  ...               0.0       0
#
# [21598 rows x 14 columns]
#                       time temp_fcst humid_fcst  ... humid_obs cloud_obs ulsan
# 0      2018-03-01 15:00:00         8         20  ...      19.0       5.0   318
# 1      2018-03-01 16:00:00   6.66667         20  ...      17.0       1.0   258
# 2      2018-03-01 17:00:00   5.33333         20  ...      17.0       2.0   160
# 3      2018-03-01 18:00:00         4         20  ...      19.0       2.0    30
# 4      2018-03-01 21:00:00         3         30  ...      25.0       8.0     0
# ...                    ...       ...        ...  ...       ...       ...   ...
# 24720  2021-01-31 19:00:00   8.81587    62.5079  ...      50.0       5.0     0
# 24721  2021-01-31 20:00:00   8.43175    66.0159  ...      49.0       1.0     0
# 24722  2021-01-31 21:00:00   8.04762    69.5238  ...      51.0       7.0     0
# 24723  2021-01-31 22:00:00    8.6075     69.228  ...      51.0       8.0     0
# 24724  2021-01-31 23:00:00   9.16739    68.9322  ...      56.0       9.0     0
#
# [24725 rows x 12 columns]
# statistical analysis with dangjin_floating: pearson correlation coefficient
# ===========================================================================
# variable: temp_fcst, pearson's r : 0.244816, p-value: 0.000000
# variable: humid_fcst, pearson's r : -0.586017, p-value: 0.000000
# variable: ws_fcst, pearson's r : 0.047482, p-value: 0.000000
# variable: wd_fcst, pearson's r : 0.096620, p-value: 0.000000
# variable: cloud_fcst, pearson's r : -0.203463, p-value: 0.000000
# variable: temp_obs, pearson's r : 0.300488, p-value: 0.000000
# variable: ws_obs, pearson's r : 0.441562, p-value: 0.000000
# variable: wd_obs, pearson's r : 0.346081, p-value: 0.000000
# variable: humid_obs, pearson's r : -0.634611, p-value: 0.000000
# variable: cloud_obs, pearson's r : -0.196116, p-value: 0.000000
# ===========================================================================
#
# statistical analysis with dangjin_warehouse: pearson correlation coefficient
# ===========================================================================
# variable: temp_fcst, pearson's r : 0.251714, p-value: 0.000000
# variable: humid_fcst, pearson's r : -0.582285, p-value: 0.000000
# variable: ws_fcst, pearson's r : 0.033596, p-value: 0.000001
# variable: wd_fcst, pearson's r : 0.097465, p-value: 0.000000
# variable: cloud_fcst, pearson's r : -0.214912, p-value: 0.000000
# variable: temp_obs, pearson's r : 0.310041, p-value: 0.000000
# variable: ws_obs, pearson's r : 0.438118, p-value: 0.000000
# variable: wd_obs, pearson's r : 0.340852, p-value: 0.000000
# variable: humid_obs, pearson's r : -0.637139, p-value: 0.000000
# variable: cloud_obs, pearson's r : -0.202771, p-value: 0.000000
# ===========================================================================
#
# statistical analysis with dangjin: pearson correlation coefficient
# ===========================================================================
# variable: temp_fcst, pearson's r : 0.231632, p-value: 0.000000
# variable: humid_fcst, pearson's r : -0.596791, p-value: 0.000000
# variable: ws_fcst, pearson's r : 0.052063, p-value: 0.000000
# variable: wd_fcst, pearson's r : 0.106940, p-value: 0.000000
# variable: cloud_fcst, pearson's r : -0.221418, p-value: 0.000000
# variable: temp_obs, pearson's r : 0.289650, p-value: 0.000000
# variable: ws_obs, pearson's r : 0.441388, p-value: 0.000000
# variable: wd_obs, pearson's r : 0.350671, p-value: 0.000000
# variable: humid_obs, pearson's r : -0.646451, p-value: 0.000000
# variable: cloud_obs, pearson's r : -0.217490, p-value: 0.000000
# ===========================================================================
#
# statistical analysis with ulsan: pearson correlation coefficient
# ===========================================================================
# variable: temp_fcst, pearson's r : 0.219543, p-value: 0.000000
# variable: humid_fcst, pearson's r : -0.421816, p-value: 0.000000
# variable: ws_fcst, pearson's r : 0.059894, p-value: 0.000000
# variable: wd_fcst, pearson's r : -0.024939, p-value: 0.000088
# variable: cloud_fcst, pearson's r : -0.202257, p-value: 0.000000
# variable: temp_obs, pearson's r : 0.251264, p-value: 0.000000
# variable: ws_obs, pearson's r : 0.308580, p-value: 0.000000
# variable: wd_obs, pearson's r : -0.194000, p-value: 0.000000
# variable: humid_obs, pearson's r : -0.449039, p-value: 0.000000
# variable: cloud_obs, pearson's r : -0.221358, p-value: 0.000000
# ===========================================================================
#
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)
# Requirement already up-to-date: xgboost in /usr/local/lib/python3.7/dist-packages (1.4.0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)

# %%
model.fit(x_train, y_train, early_stopping_rounds = 500, eval_set = [(x_test, y_test)])
# Out:
# [0]	validation_0-rmse:207.52251
# [1]	validation_0-rmse:207.33211
# [2]	validation_0-rmse:207.13878
# [3]	validation_0-rmse:206.94611
# [4]	validation_0-rmse:206.75545
# [5]	validation_0-rmse:206.56212
# [6]	validation_0-rmse:206.37007
# [7]	validation_0-rmse:206.17837
# [8]	validation_0-rmse:205.99048
# [9]	validation_0-rmse:205.80087
# [10]	validation_0-rmse:205.60770
# [11]	validation_0-rmse:205.41681
# [12]	validation_0-rmse:205.24437
# [13]	validation_0-rmse:205.05453
# [14]	validation_0-rmse:204.88088
# [15]	validation_0-rmse:204.69319
# [16]	validation_0-rmse:204.51721
# [17]	validation_0-rmse:204.32809
# [18]	validation_0-rmse:204.13711
# [19]	validation_0-rmse:203.94644
# [20]	validation_0-rmse:203.77307
# [21]	validation_0-rmse:203.58411
# [22]	validation_0-rmse:203.41031
# [23]	validation_0-rmse:203.22073
# [24]	validation_0-rmse:203.03021
# [25]	validation_0-rmse:202.85913
# [26]	validation_0-rmse:202.67282
# [27]	validation_0-rmse:202.48546
# [28]	validation_0-rmse:202.29860
# [29]	validation_0-rmse:202.11124
# [30]	validation_0-rmse:201.92369
# [31]	validation_0-rmse:201.73706
# [32]	validation_0-rmse:201.55386
# [33]	validation_0-rmse:201.36720
# [34]	validation_0-rmse:201.19869
# [35]	validation_0-rmse:201.02870
# [36]	validation_0-rmse:200.85921
# [37]	validation_0-rmse:200.68900
# [38]	validation_0-rmse:200.50290
# [39]	validation_0-rmse:200.31665
# [40]	validation_0-rmse:200.13194
# [41]	validation_0-rmse:199.95937
# [42]	validation_0-rmse:199.77309
# [43]	validation_0-rmse:199.58960
# [44]	validation_0-rmse:199.42246
# [45]	validation_0-rmse:199.23767
# [46]	validation_0-rmse:199.07219
# [47]	validation_0-rmse:198.88808
# [48]	validation_0-rmse:198.71988
# [49]	validation_0-rmse:198.55504
# [50]	validation_0-rmse:198.37051
# [51]	validation_0-rmse:198.20110
# [52]	validation_0-rmse:198.01813
# [53]	validation_0-rmse:197.83392
# [54]	validation_0-rmse:197.66887
# [55]	validation_0-rmse:197.48494
# [56]	validation_0-rmse:197.31552
# [57]	validation_0-rmse:197.13194
# [58]	validation_0-rmse:196.95013
# [59]	validation_0-rmse:196.76778
# [60]	validation_0-rmse:196.60378
# [61]	validation_0-rmse:196.42450
# [62]	validation_0-rmse:196.25868
# [63]	validation_0-rmse:196.07838
# [64]	validation_0-rmse:195.89821
# [65]	validation_0-rmse:195.71582
# [66]	validation_0-rmse:195.53453
# [67]	validation_0-rmse:195.35483
# [68]	validation_0-rmse:195.17621
# [69]	validation_0-rmse:194.99709
# [70]	validation_0-rmse:194.82790
# [71]	validation_0-rmse:194.64706
# [72]	validation_0-rmse:194.46773
# [73]	validation_0-rmse:194.29001
# [74]	validation_0-rmse:194.11261
# [75]	validation_0-rmse:193.93222
# [76]	validation_0-rmse:193.78244
# [77]	validation_0-rmse:193.61955
# [78]	validation_0-rmse:193.44196
# [79]	validation_0-rmse:193.26424
# [80]	validation_0-rmse:193.08638
# [81]	validation_0-rmse:192.90900
# [82]	validation_0-rmse:192.73325
# [83]	validation_0-rmse:192.55658
# [84]	validation_0-rmse:192.38002
# [85]	validation_0-rmse:192.21880
# [86]	validation_0-rmse:192.04332
# [87]	validation_0-rmse:191.86800
# [88]	validation_0-rmse:191.69481
# [89]	validation_0-rmse:191.54669
# [90]	validation_0-rmse:191.38783
# [91]	validation_0-rmse:191.22761
# [92]	validation_0-rmse:191.05145
# [93]	validation_0-rmse:190.87741
# [94]	validation_0-rmse:190.70308
# [95]	validation_0-rmse:190.52933
# [96]	validation_0-rmse:190.37909
# [97]	validation_0-rmse:190.20503
# [98]	validation_0-rmse:190.05633
# [99]	validation_0-rmse:189.88184
# [100]	validation_0-rmse:189.70772
# [101]	validation_0-rmse:189.53325
# [102]	validation_0-rmse:189.35854
# [103]	validation_0-rmse:189.18440
# [104]	validation_0-rmse:189.01250
# [105]	validation_0-rmse:188.85489
# [106]	validation_0-rmse:188.69367
# [107]	validation_0-rmse:188.52010
# [108]	validation_0-rmse:188.34947
# [109]	validation_0-rmse:188.17860
# [110]	validation_0-rmse:188.00804
# [111]	validation_0-rmse:187.83849
# [112]	validation_0-rmse:187.66571
# [113]	validation_0-rmse:187.49434
# [114]	validation_0-rmse:187.32243
# [115]	validation_0-rmse:187.15204
# [116]	validation_0-rmse:186.99481
# [117]	validation_0-rmse:186.82539
# [118]	validation_0-rmse:186.65619
# [119]	validation_0-rmse:186.50403
# [120]	validation_0-rmse:186.33495
# [121]	validation_0-rmse:186.16330
# [122]	validation_0-rmse:185.99248
# [123]	validation_0-rmse:185.82246
# [124]	validation_0-rmse:185.65266
# [125]	validation_0-rmse:185.49724
# [126]	validation_0-rmse:185.34662
# [127]	validation_0-rmse:185.17763
# [128]	validation_0-rmse:185.00842
# [129]	validation_0-rmse:184.83774
# [130]	validation_0-rmse:184.67035
# [131]	validation_0-rmse:184.50122
# [132]	validation_0-rmse:184.36992
# [133]	validation_0-rmse:184.21921
# [134]	validation_0-rmse:184.05093
# [135]	validation_0-rmse:183.88249
# [136]	validation_0-rmse:183.71451
# [137]	validation_0-rmse:183.54608
# [138]	validation_0-rmse:183.37862
# [139]	validation_0-rmse:183.21410
# [140]	validation_0-rmse:183.04729
# [141]	validation_0-rmse:182.88081
# [142]	validation_0-rmse:182.72763
# [143]	validation_0-rmse:182.58174
# [144]	validation_0-rmse:182.41649
# [145]	validation_0-rmse:182.26639
# [146]	validation_0-rmse:182.09779
# [147]	validation_0-rmse:181.93275
# [148]	validation_0-rmse:181.76552
# [149]	validation_0-rmse:181.60014
# [150]	validation_0-rmse:181.44840
# [151]	validation_0-rmse:181.29970
# [152]	validation_0-rmse:181.13586
# [153]	validation_0-rmse:180.97212
# [154]	validation_0-rmse:180.80806
# [155]	validation_0-rmse:180.65840
# [156]	validation_0-rmse:180.50784
# [157]	validation_0-rmse:180.34328
# [158]	validation_0-rmse:180.20216
# [159]	validation_0-rmse:180.03825
# [160]	validation_0-rmse:179.87534
# [161]	validation_0-rmse:179.72537
# [162]	validation_0-rmse:179.55953
# [163]	validation_0-rmse:179.39587
# [164]	validation_0-rmse:179.23372
# [165]	validation_0-rmse:179.07400
# [166]	validation_0-rmse:178.91182
# [167]	validation_0-rmse:178.74994
# [168]	validation_0-rmse:178.58681
# [169]	validation_0-rmse:178.42476
# [170]	validation_0-rmse:178.27818
# [171]	validation_0-rmse:178.11423
# [172]	validation_0-rmse:177.95387
# [173]	validation_0-rmse:177.79535
# [174]	validation_0-rmse:177.63467
# [175]	validation_0-rmse:177.47224
# [176]	validation_0-rmse:177.31067
# [177]	validation_0-rmse:177.14984
# [178]	validation_0-rmse:176.99208
# [179]	validation_0-rmse:176.84949
# [180]	validation_0-rmse:176.68942
# [181]	validation_0-rmse:176.52914
# [182]	validation_0-rmse:176.37126
# [183]	validation_0-rmse:176.21217
# [184]	validation_0-rmse:176.06819
# [185]	validation_0-rmse:175.90866
# [186]	validation_0-rmse:175.75185
# [187]	validation_0-rmse:175.59531
# [188]	validation_0-rmse:175.43541
# [189]	validation_0-rmse:175.28981
# [190]	validation_0-rmse:175.13019
# [191]	validation_0-rmse:174.97017
# [192]	validation_0-rmse:174.82483
# [193]	validation_0-rmse:174.66803
# [194]	validation_0-rmse:174.51273
# [195]	validation_0-rmse:174.35458
# [196]	validation_0-rmse:174.19869
# [197]	validation_0-rmse:174.04367
# [198]	validation_0-rmse:173.90033
# [199]	validation_0-rmse:173.74589
# [200]	validation_0-rmse:173.58951
# [201]	validation_0-rmse:173.43156
# [202]	validation_0-rmse:173.27611
# [203]	validation_0-rmse:173.11964
# [204]	validation_0-rmse:172.96462
# [205]	validation_0-rmse:172.80957
# [206]	validation_0-rmse:172.65471
# [207]	validation_0-rmse:172.49680
# [208]	validation_0-rmse:172.34129
# [209]	validation_0-rmse:172.18553
# [210]	validation_0-rmse:172.02992
# [211]	validation_0-rmse:171.87593
# [212]	validation_0-rmse:171.72203
# [213]	validation_0-rmse:171.58350
# [214]	validation_0-rmse:171.42850
# [215]	validation_0-rmse:171.27486
# [216]	validation_0-rmse:171.12048
# [217]	validation_0-rmse:170.96761
# [218]	validation_0-rmse:170.83173
# [219]	validation_0-rmse:170.67741
# [220]	validation_0-rmse:170.52544
# [221]	validation_0-rmse:170.37221
# [222]	validation_0-rmse:170.24583
# [223]	validation_0-rmse:170.09290
# [224]	validation_0-rmse:169.94052
# [225]	validation_0-rmse:169.78879
# [226]	validation_0-rmse:169.63794
# [227]	validation_0-rmse:169.48483
# [228]	validation_0-rmse:169.34447
# [229]	validation_0-rmse:169.19061
# [230]	validation_0-rmse:169.03757
# [231]	validation_0-rmse:168.88620
# [232]	validation_0-rmse:168.73480
# [233]	validation_0-rmse:168.59824
# [234]	validation_0-rmse:168.44807
# [235]	validation_0-rmse:168.29782
# [236]	validation_0-rmse:168.16127
# [237]	validation_0-rmse:168.03422
# [238]	validation_0-rmse:167.88359
# [239]	validation_0-rmse:167.73296
# [240]	validation_0-rmse:167.58328
# [241]	validation_0-rmse:167.43301
# [242]	validation_0-rmse:167.28343
# [243]	validation_0-rmse:167.13309
# [244]	validation_0-rmse:166.98369
# [245]	validation_0-rmse:166.83363
# [246]	validation_0-rmse:166.69931
# [247]	validation_0-rmse:166.55160
# [248]	validation_0-rmse:166.40111
# [249]	validation_0-rmse:166.25270
# [250]	validation_0-rmse:166.11719
# [251]	validation_0-rmse:165.96689
# [252]	validation_0-rmse:165.83063
# [253]	validation_0-rmse:165.68222
# [254]	validation_0-rmse:165.53368
# [255]	validation_0-rmse:165.38426
# [256]	validation_0-rmse:165.23796
# [257]	validation_0-rmse:165.08992
# [258]	validation_0-rmse:164.94327
# [259]	validation_0-rmse:164.80330
# [260]	validation_0-rmse:164.68359
# [261]	validation_0-rmse:164.53590
# [262]	validation_0-rmse:164.39961
# [263]	validation_0-rmse:164.25388
# [264]	validation_0-rmse:164.10623
# [265]	validation_0-rmse:163.96137
# [266]	validation_0-rmse:163.81549
# [267]	validation_0-rmse:163.67047
# [268]	validation_0-rmse:163.53690
# [269]	validation_0-rmse:163.39092
# [270]	validation_0-rmse:163.24457
# [271]	validation_0-rmse:163.09976
# [272]	validation_0-rmse:162.95683
# [273]	validation_0-rmse:162.81119
# [274]	validation_0-rmse:162.66801
# [275]	validation_0-rmse:162.52092
# [276]	validation_0-rmse:162.37692
# [277]	validation_0-rmse:162.23541
# [278]	validation_0-rmse:162.10147
# [279]	validation_0-rmse:161.95579
# [280]	validation_0-rmse:161.81274
# [281]	validation_0-rmse:161.68051
# [282]	validation_0-rmse:161.53784
# [283]	validation_0-rmse:161.39410
# [284]	validation_0-rmse:161.25209
# [285]	validation_0-rmse:161.12848
# [286]	validation_0-rmse:160.98546
# [287]	validation_0-rmse:160.84062
# [288]	validation_0-rmse:160.71967
# [289]	validation_0-rmse:160.57873
# [290]	validation_0-rmse:160.43543
# [291]	validation_0-rmse:160.29204
# [292]	validation_0-rmse:160.15059
# [293]	validation_0-rmse:160.00803
# [294]	validation_0-rmse:159.86655
# [295]	validation_0-rmse:159.72548
# [296]	validation_0-rmse:159.58307
# [297]	validation_0-rmse:159.45306
# [298]	validation_0-rmse:159.32663
# [299]	validation_0-rmse:159.18411
# [300]	validation_0-rmse:159.05370
# [301]	validation_0-rmse:158.91269
# [302]	validation_0-rmse:158.77112
# [303]	validation_0-rmse:158.62933
# [304]	validation_0-rmse:158.49114
# [305]	validation_0-rmse:158.34992
# [306]	validation_0-rmse:158.20996
# [307]	validation_0-rmse:158.07007
# [308]	validation_0-rmse:157.93391
# [309]	validation_0-rmse:157.79533
# [310]	validation_0-rmse:157.65732
# [311]	validation_0-rmse:157.51871
# [312]	validation_0-rmse:157.37990
# [313]	validation_0-rmse:157.24104
# [314]	validation_0-rmse:157.10316
# [315]	validation_0-rmse:156.98445
# [316]	validation_0-rmse:156.84534
# [317]	validation_0-rmse:156.70725
# [318]	validation_0-rmse:156.56857
# [319]	validation_0-rmse:156.43076
# [320]	validation_0-rmse:156.29244
# [321]	validation_0-rmse:156.16374
# [322]	validation_0-rmse:156.02506
# [323]	validation_0-rmse:155.88716
# [324]	validation_0-rmse:155.76018
# [325]	validation_0-rmse:155.62178
# [326]	validation_0-rmse:155.50362
# [327]	validation_0-rmse:155.36644
# [328]	validation_0-rmse:155.22966
# [329]	validation_0-rmse:155.10593
# [330]	validation_0-rmse:154.96974
# [331]	validation_0-rmse:154.83246
# [332]	validation_0-rmse:154.71187
# [333]	validation_0-rmse:154.57570
# [334]	validation_0-rmse:154.44069
# [335]	validation_0-rmse:154.30560
# [336]	validation_0-rmse:154.16803
# [337]	validation_0-rmse:154.03061
# [338]	validation_0-rmse:153.89671
# [339]	validation_0-rmse:153.77531
# [340]	validation_0-rmse:153.63939
# [341]	validation_0-rmse:153.50467
# [342]	validation_0-rmse:153.37036
# [343]	validation_0-rmse:153.24606
# [344]	validation_0-rmse:153.11009
# [345]	validation_0-rmse:152.97623
# [346]	validation_0-rmse:152.84029
# [347]	validation_0-rmse:152.70610
# [348]	validation_0-rmse:152.58666
# [349]	validation_0-rmse:152.45410
# [350]	validation_0-rmse:152.32121
# [351]	validation_0-rmse:152.18811
# [352]	validation_0-rmse:152.06796
# [353]	validation_0-rmse:151.93404
# [354]	validation_0-rmse:151.81325
# [355]	validation_0-rmse:151.67903
# [356]	validation_0-rmse:151.54684
# [357]	validation_0-rmse:151.41266
# [358]	validation_0-rmse:151.28114
# [359]	validation_0-rmse:151.14732
# [360]	validation_0-rmse:151.01555
# [361]	validation_0-rmse:150.88431
# [362]	validation_0-rmse:150.75444
# [363]	validation_0-rmse:150.63367
# [364]	validation_0-rmse:150.50487
# [365]	validation_0-rmse:150.37596
# [366]	validation_0-rmse:150.24236
# [367]	validation_0-rmse:150.11191
# [368]	validation_0-rmse:149.98239
# [369]	validation_0-rmse:149.85082
# [370]	validation_0-rmse:149.72244
# [371]	validation_0-rmse:149.59580
# [372]	validation_0-rmse:149.46539
# [373]	validation_0-rmse:149.33284
# [374]	validation_0-rmse:149.21294
# [375]	validation_0-rmse:149.09633
# [376]	validation_0-rmse:148.96516
# [377]	validation_0-rmse:148.83554
# [378]	validation_0-rmse:148.70766
# [379]	validation_0-rmse:148.57727
# [380]	validation_0-rmse:148.45046
# [381]	validation_0-rmse:148.32124
# [382]	validation_0-rmse:148.19179
# [383]	validation_0-rmse:148.06294
# [384]	validation_0-rmse:147.93541
# [385]	validation_0-rmse:147.80403
# [386]	validation_0-rmse:147.67505
# [387]	validation_0-rmse:147.54730
# [388]	validation_0-rmse:147.42989
# [389]	validation_0-rmse:147.31386
# [390]	validation_0-rmse:147.18741
# [391]	validation_0-rmse:147.06094
# [392]	validation_0-rmse:146.93398
# [393]	validation_0-rmse:146.80425
# [394]	validation_0-rmse:146.67541
# [395]	validation_0-rmse:146.54936
# [396]	validation_0-rmse:146.42319
# [397]	validation_0-rmse:146.29570
# [398]	validation_0-rmse:146.16899
# [399]	validation_0-rmse:146.04112
# [400]	validation_0-rmse:145.91417
# [401]	validation_0-rmse:145.78894
# [402]	validation_0-rmse:145.66405
# [403]	validation_0-rmse:145.53882
# [404]	validation_0-rmse:145.41379
# [405]	validation_0-rmse:145.28885
# [406]	validation_0-rmse:145.16403
# [407]	validation_0-rmse:145.03819
# [408]	validation_0-rmse:144.91223
# [409]	validation_0-rmse:144.79767
# [410]	validation_0-rmse:144.67213
# [411]	validation_0-rmse:144.54452
# [412]	validation_0-rmse:144.41971
# [413]	validation_0-rmse:144.29481
# [414]	validation_0-rmse:144.16907
# [415]	validation_0-rmse:144.04352
# [416]	validation_0-rmse:143.92261
# [417]	validation_0-rmse:143.79825
# [418]	validation_0-rmse:143.67423
# [419]	validation_0-rmse:143.55096
# [420]	validation_0-rmse:143.42918
# [421]	validation_0-rmse:143.30498
# [422]	validation_0-rmse:143.18060
# [423]	validation_0-rmse:143.05699
# [424]	validation_0-rmse:142.93364
# [425]	validation_0-rmse:142.81000
# [426]	validation_0-rmse:142.68896
# [427]	validation_0-rmse:142.56636
# [428]	validation_0-rmse:142.45399
# [429]	validation_0-rmse:142.33077
# [430]	validation_0-rmse:142.20934
# [431]	validation_0-rmse:142.08733
# [432]	validation_0-rmse:141.96530
# [433]	validation_0-rmse:141.85570
# [434]	validation_0-rmse:141.73222
# [435]	validation_0-rmse:141.61186
# [436]	validation_0-rmse:141.49037
# [437]	validation_0-rmse:141.36989
# [438]	validation_0-rmse:141.26769
# [439]	validation_0-rmse:141.14739
# [440]	validation_0-rmse:141.02519
# [441]	validation_0-rmse:140.90242
# [442]	validation_0-rmse:140.78236
# [443]	validation_0-rmse:140.66157
# [444]	validation_0-rmse:140.54117
# [445]	validation_0-rmse:140.42894
# [446]	validation_0-rmse:140.30875
# [447]	validation_0-rmse:140.18932
# [448]	validation_0-rmse:140.06953
# [449]	validation_0-rmse:139.96573
# [450]	validation_0-rmse:139.86070
# [451]	validation_0-rmse:139.74211
# [452]	validation_0-rmse:139.62248
# [453]	validation_0-rmse:139.51434
# [454]	validation_0-rmse:139.39619
# [455]	validation_0-rmse:139.27695
# [456]	validation_0-rmse:139.16740
# [457]	validation_0-rmse:139.04835
# [458]	validation_0-rmse:138.93964
# [459]	validation_0-rmse:138.81982
# [460]	validation_0-rmse:138.70332
# [461]	validation_0-rmse:138.58467
# [462]	validation_0-rmse:138.46707
# [463]	validation_0-rmse:138.35857
# [464]	validation_0-rmse:138.23840
# [465]	validation_0-rmse:138.11983
# [466]	validation_0-rmse:138.00136
# [467]	validation_0-rmse:137.88478
# [468]	validation_0-rmse:137.76938
# [469]	validation_0-rmse:137.65195
# [470]	validation_0-rmse:137.53438
# [471]	validation_0-rmse:137.41792
# [472]	validation_0-rmse:137.31313
# [473]	validation_0-rmse:137.19676
# [474]	validation_0-rmse:137.08049
# [475]	validation_0-rmse:136.96552
# [476]	validation_0-rmse:136.84786
# [477]	validation_0-rmse:136.74600
# [478]	validation_0-rmse:136.63016
# [479]	validation_0-rmse:136.51482
# [480]	validation_0-rmse:136.39851
# [481]	validation_0-rmse:136.28247
# [482]	validation_0-rmse:136.17629
# [483]	validation_0-rmse:136.07596
# [484]	validation_0-rmse:135.96016
# [485]	validation_0-rmse:135.84328
# [486]	validation_0-rmse:135.73759
# [487]	validation_0-rmse:135.63139
# [488]	validation_0-rmse:135.51836
# [489]	validation_0-rmse:135.40366
# [490]	validation_0-rmse:135.28815
# [491]	validation_0-rmse:135.18329
# [492]	validation_0-rmse:135.06850
# [493]	validation_0-rmse:134.95309
# [494]	validation_0-rmse:134.83872
# [495]	validation_0-rmse:134.72639
# [496]	validation_0-rmse:134.61394
# [497]	validation_0-rmse:134.50232
# [498]	validation_0-rmse:134.38853
# [499]	validation_0-rmse:134.27573
# [500]	validation_0-rmse:134.17394
# [501]	validation_0-rmse:134.06058
# [502]	validation_0-rmse:133.94789
# [503]	validation_0-rmse:133.83295
# [504]	validation_0-rmse:133.72142
# [505]	validation_0-rmse:133.61024
# [506]	validation_0-rmse:133.49919
# [507]	validation_0-rmse:133.38602
# [508]	validation_0-rmse:133.27280
# [509]	validation_0-rmse:133.15887
# [510]	validation_0-rmse:133.06599
# [511]	validation_0-rmse:132.95306
# [512]	validation_0-rmse:132.84021
# [513]	validation_0-rmse:132.72816
# [514]	validation_0-rmse:132.61713
# [515]	validation_0-rmse:132.51692
# [516]	validation_0-rmse:132.40762
# [517]	validation_0-rmse:132.29572
# [518]	validation_0-rmse:132.20229
# [519]	validation_0-rmse:132.09085
# [520]	validation_0-rmse:131.97911
# [521]	validation_0-rmse:131.88107
# [522]	validation_0-rmse:131.76894
# [523]	validation_0-rmse:131.65904
# [524]	validation_0-rmse:131.54738
# [525]	validation_0-rmse:131.45758
# [526]	validation_0-rmse:131.34764
# [527]	validation_0-rmse:131.23700
# [528]	validation_0-rmse:131.12804
# [529]	validation_0-rmse:131.03473
# [530]	validation_0-rmse:130.92467
# [531]	validation_0-rmse:130.81570
# [532]	validation_0-rmse:130.70515
# [533]	validation_0-rmse:130.59520
# [534]	validation_0-rmse:130.48599
# [535]	validation_0-rmse:130.39195
# [536]	validation_0-rmse:130.28630
# [537]	validation_0-rmse:130.18475
# [538]	validation_0-rmse:130.07573
# [539]	validation_0-rmse:129.96812
# [540]	validation_0-rmse:129.85954
# [541]	validation_0-rmse:129.74814
# [542]	validation_0-rmse:129.64076
# [543]	validation_0-rmse:129.53230
# [544]	validation_0-rmse:129.42450
# [545]	validation_0-rmse:129.32394
# [546]	validation_0-rmse:129.22624
# [547]	validation_0-rmse:129.13028
# [548]	validation_0-rmse:129.02252
# [549]	validation_0-rmse:128.91373
# [550]	validation_0-rmse:128.80489
# [551]	validation_0-rmse:128.69995
# [552]	validation_0-rmse:128.59114
# [553]	validation_0-rmse:128.48544
# [554]	validation_0-rmse:128.37799
# [555]	validation_0-rmse:128.28168
# [556]	validation_0-rmse:128.18562
# [557]	validation_0-rmse:128.08064
# [558]	validation_0-rmse:127.97437
# [559]	validation_0-rmse:127.87797
# [560]	validation_0-rmse:127.77167
# [561]	validation_0-rmse:127.67416
# [562]	validation_0-rmse:127.56846
# [563]	validation_0-rmse:127.47131
# [564]	validation_0-rmse:127.36707
# [565]	validation_0-rmse:127.26297
# [566]	validation_0-rmse:127.15907
# [567]	validation_0-rmse:127.05366
# [568]	validation_0-rmse:126.96693
# [569]	validation_0-rmse:126.86215
# [570]	validation_0-rmse:126.75677
# [571]	validation_0-rmse:126.65334
# [572]	validation_0-rmse:126.54899
# [573]	validation_0-rmse:126.44684
# [574]	validation_0-rmse:126.34212
# [575]	validation_0-rmse:126.23598
# [576]	validation_0-rmse:126.13246
# [577]	validation_0-rmse:126.02756
# [578]	validation_0-rmse:125.92393
# [579]	validation_0-rmse:125.82190
# [580]	validation_0-rmse:125.71822
# [581]	validation_0-rmse:125.61385
# [582]	validation_0-rmse:125.51116
# [583]	validation_0-rmse:125.40775
# [584]	validation_0-rmse:125.30488
# [585]	validation_0-rmse:125.21222
# [586]	validation_0-rmse:125.10931
# [587]	validation_0-rmse:125.00717
# [588]	validation_0-rmse:124.90430
# [589]	validation_0-rmse:124.80099
# [590]	validation_0-rmse:124.69852
# [591]	validation_0-rmse:124.59669
# [592]	validation_0-rmse:124.49420
# [593]	validation_0-rmse:124.40057
# [594]	validation_0-rmse:124.30597
# [595]	validation_0-rmse:124.21085
# [596]	validation_0-rmse:124.11803
# [597]	validation_0-rmse:124.01737
# [598]	validation_0-rmse:123.91647
# [599]	validation_0-rmse:123.82325
# [600]	validation_0-rmse:123.72033
# [601]	validation_0-rmse:123.61762
# [602]	validation_0-rmse:123.51593
# [603]	validation_0-rmse:123.41575
# [604]	validation_0-rmse:123.32234
# [605]	validation_0-rmse:123.21941
# [606]	validation_0-rmse:123.11830
# [607]	validation_0-rmse:123.02952
# [608]	validation_0-rmse:122.92948
# [609]	validation_0-rmse:122.83028
# [610]	validation_0-rmse:122.72860
# [611]	validation_0-rmse:122.63059
# [612]	validation_0-rmse:122.52988
# [613]	validation_0-rmse:122.43967
# [614]	validation_0-rmse:122.34138
# [615]	validation_0-rmse:122.24213
# [616]	validation_0-rmse:122.14260
# [617]	validation_0-rmse:122.05733
# [618]	validation_0-rmse:121.96730
# [619]	validation_0-rmse:121.86856
# [620]	validation_0-rmse:121.77691
# [621]	validation_0-rmse:121.67969
# [622]	validation_0-rmse:121.59204
# [623]	validation_0-rmse:121.49496
# [624]	validation_0-rmse:121.39594
# [625]	validation_0-rmse:121.29745
# [626]	validation_0-rmse:121.20026
# [627]	validation_0-rmse:121.11204
# [628]	validation_0-rmse:121.01349
# [629]	validation_0-rmse:120.91450
# [630]	validation_0-rmse:120.81833
# [631]	validation_0-rmse:120.73534
# [632]	validation_0-rmse:120.65244
# [633]	validation_0-rmse:120.55454
# [634]	validation_0-rmse:120.45699
# [635]	validation_0-rmse:120.35872
# [636]	validation_0-rmse:120.26214
# [637]	validation_0-rmse:120.16378
# [638]	validation_0-rmse:120.06562
# [639]	validation_0-rmse:119.97790
# [640]	validation_0-rmse:119.88040
# [641]	validation_0-rmse:119.78219
# [642]	validation_0-rmse:119.68363
# [643]	validation_0-rmse:119.60094
# [644]	validation_0-rmse:119.51225
# [645]	validation_0-rmse:119.41454
# [646]	validation_0-rmse:119.31923
# [647]	validation_0-rmse:119.22405
# [648]	validation_0-rmse:119.13655
# [649]	validation_0-rmse:119.04144
# [650]	validation_0-rmse:118.94400
# [651]	validation_0-rmse:118.85995
# [652]	validation_0-rmse:118.76516
# [653]	validation_0-rmse:118.67020
# [654]	validation_0-rmse:118.57440
# [655]	validation_0-rmse:118.47930
# [656]	validation_0-rmse:118.39033
# [657]	validation_0-rmse:118.29565
# [658]	validation_0-rmse:118.21085
# [659]	validation_0-rmse:118.11407
# [660]	validation_0-rmse:118.02129
# [661]	validation_0-rmse:117.92731
# [662]	validation_0-rmse:117.83297
# [663]	validation_0-rmse:117.73929
# [664]	validation_0-rmse:117.64503
# [665]	validation_0-rmse:117.55110
# [666]	validation_0-rmse:117.45873
# [667]	validation_0-rmse:117.38087
# [668]	validation_0-rmse:117.28529
# [669]	validation_0-rmse:117.20361
# [670]	validation_0-rmse:117.11932
# [671]	validation_0-rmse:117.02619
# [672]	validation_0-rmse:116.93279
# [673]	validation_0-rmse:116.84035
# [674]	validation_0-rmse:116.74684
# [675]	validation_0-rmse:116.65600
# [676]	validation_0-rmse:116.56249
# [677]	validation_0-rmse:116.46881
# [678]	validation_0-rmse:116.38398
# [679]	validation_0-rmse:116.28864
# [680]	validation_0-rmse:116.19671
# [681]	validation_0-rmse:116.10255
# [682]	validation_0-rmse:116.00940
# [683]	validation_0-rmse:115.91850
# [684]	validation_0-rmse:115.82742
# [685]	validation_0-rmse:115.73550
# [686]	validation_0-rmse:115.64393
# [687]	validation_0-rmse:115.55203
# [688]	validation_0-rmse:115.46081
# [689]	validation_0-rmse:115.36956
# [690]	validation_0-rmse:115.27970
# [691]	validation_0-rmse:115.18855
# [692]	validation_0-rmse:115.09722
# [693]	validation_0-rmse:115.00452
# [694]	validation_0-rmse:114.91217
# [695]	validation_0-rmse:114.82268
# [696]	validation_0-rmse:114.73209
# [697]	validation_0-rmse:114.64242
# [698]	validation_0-rmse:114.56106
# [699]	validation_0-rmse:114.47951
# [700]	validation_0-rmse:114.38731
# [701]	validation_0-rmse:114.29781
# [702]	validation_0-rmse:114.20828
# [703]	validation_0-rmse:114.11757
# [704]	validation_0-rmse:114.02754
# [705]	validation_0-rmse:113.93777
# [706]	validation_0-rmse:113.85812
# [707]	validation_0-rmse:113.76878
# [708]	validation_0-rmse:113.67838
# [709]	validation_0-rmse:113.58807
# [710]	validation_0-rmse:113.50797
# [711]	validation_0-rmse:113.41985
# [712]	validation_0-rmse:113.32912
# [713]	validation_0-rmse:113.25031
# [714]	validation_0-rmse:113.16172
# [715]	validation_0-rmse:113.07103
# [716]	validation_0-rmse:113.00015
# [717]	validation_0-rmse:112.91035
# [718]	validation_0-rmse:112.82992
# [719]	validation_0-rmse:112.74987
# [720]	validation_0-rmse:112.66111
# [721]	validation_0-rmse:112.57333
# [722]	validation_0-rmse:112.48274
# [723]	validation_0-rmse:112.39429
# [724]	validation_0-rmse:112.30421
# [725]	validation_0-rmse:112.21522
# [726]	validation_0-rmse:112.12834
# [727]	validation_0-rmse:112.04050
# [728]	validation_0-rmse:111.95212
# [729]	validation_0-rmse:111.86339
# [730]	validation_0-rmse:111.77397
# [731]	validation_0-rmse:111.68628
# [732]	validation_0-rmse:111.60001
# [733]	validation_0-rmse:111.51172
# [734]	validation_0-rmse:111.42670
# [735]	validation_0-rmse:111.33915
# [736]	validation_0-rmse:111.25319
# [737]	validation_0-rmse:111.17596
# [738]	validation_0-rmse:111.09665
# [739]	validation_0-rmse:111.00996
# [740]	validation_0-rmse:110.92339
# [741]	validation_0-rmse:110.83890
# [742]	validation_0-rmse:110.75908
# [743]	validation_0-rmse:110.67279
# [744]	validation_0-rmse:110.58791
# [745]	validation_0-rmse:110.50233
# [746]	validation_0-rmse:110.41540
# [747]	validation_0-rmse:110.33784
# [748]	validation_0-rmse:110.25784
# [749]	validation_0-rmse:110.17285
# [750]	validation_0-rmse:110.10206
# [751]	validation_0-rmse:110.01765
# [752]	validation_0-rmse:109.93432
# [753]	validation_0-rmse:109.84759
# [754]	validation_0-rmse:109.76051
# [755]	validation_0-rmse:109.67484
# [756]	validation_0-rmse:109.60059
# [757]	validation_0-rmse:109.51331
# [758]	validation_0-rmse:109.42872
# [759]	validation_0-rmse:109.35183
# [760]	validation_0-rmse:109.27656
# [761]	validation_0-rmse:109.20197
# [762]	validation_0-rmse:109.11790
# [763]	validation_0-rmse:109.05009
# [764]	validation_0-rmse:108.98211
# [765]	validation_0-rmse:108.90556
# [766]	validation_0-rmse:108.83036
# [767]	validation_0-rmse:108.74472
# [768]	validation_0-rmse:108.66004
# [769]	validation_0-rmse:108.57649
# [770]	validation_0-rmse:108.49237
# [771]	validation_0-rmse:108.41721
# [772]	validation_0-rmse:108.33467
# [773]	validation_0-rmse:108.25150
# [774]	validation_0-rmse:108.16821
# [775]	validation_0-rmse:108.09107
# [776]	validation_0-rmse:108.00970
# [777]	validation_0-rmse:107.92807
# [778]	validation_0-rmse:107.84614
# [779]	validation_0-rmse:107.76356
# [780]	validation_0-rmse:107.68182
# [781]	validation_0-rmse:107.59939
# [782]	validation_0-rmse:107.51745
# [783]	validation_0-rmse:107.43464
# [784]	validation_0-rmse:107.35200
# [785]	validation_0-rmse:107.26885
# [786]	validation_0-rmse:107.18749
# [787]	validation_0-rmse:107.10402
# [788]	validation_0-rmse:107.02044
# [789]	validation_0-rmse:106.94766
# [790]	validation_0-rmse:106.87316
# [791]	validation_0-rmse:106.78973
# [792]	validation_0-rmse:106.70757
# [793]	validation_0-rmse:106.62699
# [794]	validation_0-rmse:106.54573
# [795]	validation_0-rmse:106.46257
# [796]	validation_0-rmse:106.38126
# [797]	validation_0-rmse:106.30833
# [798]	validation_0-rmse:106.23666
# [799]	validation_0-rmse:106.15645
# [800]	validation_0-rmse:106.08363
# [801]	validation_0-rmse:106.00268
# [802]	validation_0-rmse:105.92250
# [803]	validation_0-rmse:105.84260
# [804]	validation_0-rmse:105.76434
# [805]	validation_0-rmse:105.68405
# [806]	validation_0-rmse:105.61275
# [807]	validation_0-rmse:105.54249
# [808]	validation_0-rmse:105.46257
# [809]	validation_0-rmse:105.39124
# [810]	validation_0-rmse:105.31143
# [811]	validation_0-rmse:105.23224
# [812]	validation_0-rmse:105.15260
# [813]	validation_0-rmse:105.07392
# [814]	validation_0-rmse:104.99327
# [815]	validation_0-rmse:104.91366
# [816]	validation_0-rmse:104.83659
# [817]	validation_0-rmse:104.75722
# [818]	validation_0-rmse:104.68073
# [819]	validation_0-rmse:104.60178
# [820]	validation_0-rmse:104.52156
# [821]	validation_0-rmse:104.44299
# [822]	validation_0-rmse:104.36329
# [823]	validation_0-rmse:104.28536
# [824]	validation_0-rmse:104.21491
# [825]	validation_0-rmse:104.13621
# [826]	validation_0-rmse:104.05662
# [827]	validation_0-rmse:103.99202
# [828]	validation_0-rmse:103.92149
# [829]	validation_0-rmse:103.85218
# [830]	validation_0-rmse:103.77364
# [831]	validation_0-rmse:103.69531
# [832]	validation_0-rmse:103.61818
# [833]	validation_0-rmse:103.54076
# [834]	validation_0-rmse:103.46406
# [835]	validation_0-rmse:103.38840
# [836]	validation_0-rmse:103.31032
# [837]	validation_0-rmse:103.23325
# [838]	validation_0-rmse:103.15717
# [839]	validation_0-rmse:103.08012
# [840]	validation_0-rmse:103.01016
# [841]	validation_0-rmse:102.94236
# [842]	validation_0-rmse:102.86646
# [843]	validation_0-rmse:102.79880
# [844]	validation_0-rmse:102.71997
# [845]	validation_0-rmse:102.64368
# [846]	validation_0-rmse:102.56847
# [847]	validation_0-rmse:102.49250
# [848]	validation_0-rmse:102.41661
# [849]	validation_0-rmse:102.34044
# [850]	validation_0-rmse:102.27300
# [851]	validation_0-rmse:102.20891
# [852]	validation_0-rmse:102.13228
# [853]	validation_0-rmse:102.07098
# [854]	validation_0-rmse:101.99464
# [855]	validation_0-rmse:101.91870
# [856]	validation_0-rmse:101.84126
# [857]	validation_0-rmse:101.76491
# [858]	validation_0-rmse:101.69807
# [859]	validation_0-rmse:101.62217
# [860]	validation_0-rmse:101.54638
# [861]	validation_0-rmse:101.47229
# [862]	validation_0-rmse:101.39674
# [863]	validation_0-rmse:101.32059
# [864]	validation_0-rmse:101.25371
# [865]	validation_0-rmse:101.17963
# [866]	validation_0-rmse:101.10759
# [867]	validation_0-rmse:101.03196
# [868]	validation_0-rmse:100.96515
# [869]	validation_0-rmse:100.89780
# [870]	validation_0-rmse:100.83179
# [871]	validation_0-rmse:100.76366
# [872]	validation_0-rmse:100.69817
# [873]	validation_0-rmse:100.62350
# [874]	validation_0-rmse:100.54896
# [875]	validation_0-rmse:100.47446
# [876]	validation_0-rmse:100.39952
# [877]	validation_0-rmse:100.33186
# [878]	validation_0-rmse:100.25770
# [879]	validation_0-rmse:100.18333
# [880]	validation_0-rmse:100.11018
# [881]	validation_0-rmse:100.04491
# [882]	validation_0-rmse:99.97199
# [883]	validation_0-rmse:99.90788
# [884]	validation_0-rmse:99.83388
# [885]	validation_0-rmse:99.76180
# [886]	validation_0-rmse:99.68953
# [887]	validation_0-rmse:99.61720
# [888]	validation_0-rmse:99.54266
# [889]	validation_0-rmse:99.46886
# [890]	validation_0-rmse:99.39620
# [891]	validation_0-rmse:99.33057
# [892]	validation_0-rmse:99.25822
# [893]	validation_0-rmse:99.18588
# [894]	validation_0-rmse:99.12059
# [895]	validation_0-rmse:99.04896
# [896]	validation_0-rmse:98.98805
# [897]	validation_0-rmse:98.91537
# [898]	validation_0-rmse:98.84326
# [899]	validation_0-rmse:98.77241
# [900]	validation_0-rmse:98.71141
# [901]	validation_0-rmse:98.63939
# [902]	validation_0-rmse:98.56710
# [903]	validation_0-rmse:98.50480
# [904]	validation_0-rmse:98.43356
# [905]	validation_0-rmse:98.37087
# [906]	validation_0-rmse:98.29943
# [907]	validation_0-rmse:98.22957
# [908]	validation_0-rmse:98.15775
# [909]	validation_0-rmse:98.08566
# [910]	validation_0-rmse:98.02682
# [911]	validation_0-rmse:97.95428
# [912]	validation_0-rmse:97.88405
# [913]	validation_0-rmse:97.81349
# [914]	validation_0-rmse:97.74289
# [915]	validation_0-rmse:97.67351
# [916]	validation_0-rmse:97.60403
# [917]	validation_0-rmse:97.53394
# [918]	validation_0-rmse:97.46124
# [919]	validation_0-rmse:97.39196
# [920]	validation_0-rmse:97.32092
# [921]	validation_0-rmse:97.25020
# [922]	validation_0-rmse:97.18689
# [923]	validation_0-rmse:97.11659
# [924]	validation_0-rmse:97.04821
# [925]	validation_0-rmse:96.98035
# [926]	validation_0-rmse:96.91159
# [927]	validation_0-rmse:96.84199
# [928]	validation_0-rmse:96.77333
# [929]	validation_0-rmse:96.70335
# [930]	validation_0-rmse:96.64647
# [931]	validation_0-rmse:96.58338
# [932]	validation_0-rmse:96.51526
# [933]	validation_0-rmse:96.44783
# [934]	validation_0-rmse:96.37858
# [935]	validation_0-rmse:96.31631
# [936]	validation_0-rmse:96.24669
# [937]	validation_0-rmse:96.17794
# [938]	validation_0-rmse:96.10991
# [939]	validation_0-rmse:96.03990
# [940]	validation_0-rmse:95.97251
# [941]	validation_0-rmse:95.90343
# [942]	validation_0-rmse:95.83388
# [943]	validation_0-rmse:95.76566
# [944]	validation_0-rmse:95.69622
# [945]	validation_0-rmse:95.63648
# [946]	validation_0-rmse:95.57729
# [947]	validation_0-rmse:95.51174
# [948]	validation_0-rmse:95.44279
# [949]	validation_0-rmse:95.37562
# [950]	validation_0-rmse:95.30821
# [951]	validation_0-rmse:95.23942
# [952]	validation_0-rmse:95.17158
# [953]	validation_0-rmse:95.10480
# [954]	validation_0-rmse:95.03968
# [955]	validation_0-rmse:94.97227
# [956]	validation_0-rmse:94.91227
# [957]	validation_0-rmse:94.84555
# [958]	validation_0-rmse:94.77891
# [959]	validation_0-rmse:94.71291
# [960]	validation_0-rmse:94.64912
# [961]	validation_0-rmse:94.58279
# [962]	validation_0-rmse:94.51424
# [963]	validation_0-rmse:94.44869
# [964]	validation_0-rmse:94.38248
# [965]	validation_0-rmse:94.31823
# [966]	validation_0-rmse:94.25070
# [967]	validation_0-rmse:94.18372
# [968]	validation_0-rmse:94.11820
# [969]	validation_0-rmse:94.05293
# [970]	validation_0-rmse:93.98760
# [971]	validation_0-rmse:93.92293
# [972]	validation_0-rmse:93.85453
# [973]	validation_0-rmse:93.78858
# [974]	validation_0-rmse:93.72317
# [975]	validation_0-rmse:93.65861
# [976]	validation_0-rmse:93.59404
# [977]	validation_0-rmse:93.53474
# [978]	validation_0-rmse:93.47006
# [979]	validation_0-rmse:93.40431
# [980]	validation_0-rmse:93.34013
# [981]	validation_0-rmse:93.27454
# [982]	validation_0-rmse:93.20958
# [983]	validation_0-rmse:93.15030
# [984]	validation_0-rmse:93.08591
# [985]	validation_0-rmse:93.02219
# [986]	validation_0-rmse:92.95908
# [987]	validation_0-rmse:92.89430
# [988]	validation_0-rmse:92.83547
# [989]	validation_0-rmse:92.77045
# [990]	validation_0-rmse:92.70692
# [991]	validation_0-rmse:92.64424
# [992]	validation_0-rmse:92.58810
# [993]	validation_0-rmse:92.52555
# [994]	validation_0-rmse:92.46013
# [995]	validation_0-rmse:92.39613
# [996]	validation_0-rmse:92.33735
# [997]	validation_0-rmse:92.27191
# [998]	validation_0-rmse:92.20889
# [999]	validation_0-rmse:92.14452
# XGBRegressor(base_score=0.5, booster='dart', colsample_bylevel=0.8,
#              colsample_bynode=1, colsample_bytree=0.8, gamma=10.0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.001, max_delta_step=0, max_depth=15,
#              min_child_weight=3, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=4, nthread=-1, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0.1,
#              reg_lambda=1.0, scale_pos_weight=1, subsample=0.8,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# submission_prediction

def submission_predict(models, x_data, n_predict):
    '''
    - for multi-varaible prediction
    - x_data:(timesteps, n_features)
    - n_predict: timesteps for forecasting
    - x_data_after: x_data[1:] + predict_value
    '''
    total_prediction = None
    y_preds = []
    x_data_after = x_data

    for i in range(n_predict):
        y_preds = []
        for j in range(n_features):
            y_pred = models[j].predict(x_data_after)
            y_preds.append(y_pred)

        y_preds = np.array(y_preds).reshape(1,-1)
        x_data_after = np.concatenate((x_data_after, y_preds), axis = 1)[0,n_features:].reshape(1,-1)
        

        if total_prediction is None:
            total_prediction = y_preds
        else:
            total_prediction = np.concatenate((total_prediction, y_preds), axis = 0)
    
    total_prediction = total_prediction.reshape(-1, n_features)

    return total_prediction

# test
input_prediction = dangjin_data[x_name][-24*30*1 - n_in:-24*30*1].values.reshape(1,-1)
actual = dangjin_data[y_name][-24*30*1:].values
prediction = submission_predict([model], input_prediction, n_predict = 24 * 30)

plt.title("dangjin_floating prediction")
yreal = actual.reshape(-1,1)
yhat = prediction.reshape(-1, 1)
plt.plot(yreal, "r", label = "actual")
plt.plot(yhat, "b", label = "forecast")
plt.legend()
plt.show()
